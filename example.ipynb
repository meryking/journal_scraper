# %%
print("hello world")
# Out:
# hello world

# %%
day="Monday"

# %%
day="Tuesday"

# %%
print("Today is", day)
# Out:
# Today is Tuesday

# %%
import numpy
random_number = numpy.random.randint(low=1,high=100,size=2)
print(random_number)
# Out:
# [87 52]

# %%
llista_missatges = ["Hola", "Adeu", "Fins aviat"]
print(type(llista_missatges))
# Out:
# <class 'list'>

# %%
import numpy
random_number = numpy.random.randint(low=0,high=3)
numpy.random.randint as 
print(random_number)
llista_missatges = ["Hola", "Adeu", "Fins aviat"]
print(llista_missatges[random_number])
# Out:
# 0
# Hola

# %%
def myfunc():
    import numpy
    random_number = numpy.random.randint(low=0,high=3)
    print(random_number)
    llista_missatges = ["Hola", "Adeu", "Fins aviat"]
    print(llista_missatges[random_number])

# %%
myfunc()
# Out:
# 0
# Hola

# %%
import numpy as np
import matplotlib.pyplot as plt
random_numbers = np.random.randint(low=0,high=100, size=100)
random_numbers
# Out:
# array([62, 83, 67, 51, 41, 96, 59, 24, 58, 59, 72, 71,  2, 28, 46, 67, 50,
#        38, 92, 62, 93, 50, 37, 92, 51, 75, 21, 37, 77, 80, 79, 12, 61, 52,
#        73, 99, 69, 54, 91, 18, 12, 42, 43, 84, 75, 86, 92, 24, 88, 83,  7,
#        27,  9, 87, 57, 54,  8, 90, 98, 53, 83, 86, 92, 58,  0, 28, 62, 33,
#        80, 98, 76,  3, 41, 10, 40, 22, 84, 55, 35, 59, 63, 61, 46, 55, 55,
#        90, 47, 57, 12, 20, 38, 45, 56, 19, 20, 37, 56, 77, 35, 96])

# %%
plt.plot(random_numbers)
#discontinous red line that marks the average
plt.axhline(y=np.mean(random_numbers), color='r', linestyle='--')

# %%
import requests
from bs4 import BeautifulSoup
url="https://www.ara.cat/economia/immobiliari/sanchez-promet-mes-bonificacions-fiscals-als-propietaris-posin-pis-lloguer_1_5253414.html"
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')
print(page.content)
# Out:
# b'\n<!doctype html>\n<html lang="ca">\n<head>\n    <!-- bbnx generated at 2025-01-13T18:24:40+01:00 -->\n            <title>S\xc3\xa1nchez promet m\xc3\xa9s bonificacions fiscals als propietaris que posin el pis a lloguer</title>\n    \n    <meta name="description" content="El govern espanyol arrenca l&#039;any amb una bateria de mesures en mat\xc3\xa8ria habitacional">\n            <link rel="canonical" href="https://www.ara.cat/economia/immobiliari/sanchez-promet-mes-bonificacions-fiscals-als-propietaris-posin-pis-lloguer_1_5253414.html">                    \n    <link rel="manifest" href="/api/front/manifest.json">    <meta property="article:modified_time" content="2025-01-13T13:50:09+01:00">    <meta property="article:published_time" content="2025-01-13T13:14:57+01:00">    <meta property="article:section" content="Immobiliari">    <meta property="article:tag" content="habitatge">    <meta name="author" content="N\xc3\xbaria Rius Montaner">    <meta http-equiv="Content-Type" conte
# ...

# %%
import requests
from bs4 import BeautifulSoup
url="https://www.ara.cat/economia/immobiliari/sanchez-promet-mes-bonificacions-fiscals-als-propietaris-posin-pis-lloguer_1_5253414.html"
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')
#find the text under div class ara-body
text = soup.find_all('div', class_='ara-body')  
print(text)
# Out:
# [<div class="ara-body">
# <p><span class="place">Madrid</span>L’habitatge marca el tret de sortida del nou any. Des de fa setmanes, el govern espanyol treballa en més mesures que ajudin a pal·liar el problema de l’accés a l'habitatge, una qüestió que s’ha convertit en una de les principals preocupacions socials, sobretot entre els joves. I aquest dilluns, el mateix president espanyol, Pedro Sánchez, ha estat l’encarregat de desgranar les propostes i ho ha fet acompanyat de gairebé tots els ministres. Una mostra més de com l'executiu central vol fer d'aquesta matèria un dels pals de paller de la legislatura.  </p>
# <div class="ara-newsletter">
# <div class="ara-newsletter-wrapper">
# <picture class="ara-newsletter--image">
# <img alt="" class="no-sources lazy" data-src="https://static1.ara.cat/ara/public/file/2024/1007/10/quart-sense-ascensor.png" src='data:image/svg+xml,%3Csvg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 56 56"%3E%3C/svg%3E'/>
# </picture>
# ...
